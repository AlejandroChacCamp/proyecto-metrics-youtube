# %%
import requests
import json
import os
import time

# %%
os.chdir("C:/Users/victo/Desktop/proyecto-metrics-youtube/02_proyecto_principal")

with open("keys.txt", "r") as file:
    linea = file.read().strip()
    API_KEY = linea.split("=",1)[1]

# %% [markdown]
# ### **Dividir lista de 50 comments en batch de 50 (MaxResults)**

# %%
lista_prueba_1 = list(range(200))
print(lista_prueba_1)

lista_prueba_2 = list(range(0,len(lista_prueba_1),50))
print(lista_prueba_2)

lista_vacia = []

for i in lista_prueba_2:
    lista_pequeña = []
    for j in lista_prueba_1[0:i]:
        lista_pequeña.append(j)
        #print(f"esta es la lista pequeña: {lista_pequeña}")
    lista_vacia.append(lista_pequeña)
print(lista_vacia)

# %%
lista_prueba_1 = list(range(200))  # 0..200

# Opción 1: usando range con paso 50
bloques = []
for inicio in range(0, len(lista_prueba_1), 50):
    fin = inicio + 50
    bloque = lista_prueba_1[inicio:fin]  # el slicing se detiene al final de la lista automáticamente
    bloques.append(bloque)

print(bloques)

# %%
detalles_videos = []
for inicio in range(0, len(video_id_lista), 50):
    bloque = video_id_lista[inicio:inicio+50]
    ids_str = ",".join(bloque)

# %% [markdown]
# ### **Probar endpoint videos (lista)**

# %%
import requests
import json
import os

# %%
os.chdir("C:/Users/victo/Desktop/proyecto-metrics-youtube/02_proyecto_principal")

with open("keys.txt", "r") as file:
    linea = file.read().strip()
    API_KEY = linea.split("=",1)[1]

# %%
def hacer_peticion(url, params, max_retries=3):
    """
    Realiza una petición GET con reintentos en caso de error.
    
    Args:
        url (str): La URL de la API.
        params (dict): Parámetros de la consulta.
        max_retries (int): Número máximo de intentos.
    
    Returns:
        dict or None: El JSON de la respuesta si es exitosa, None si falla tras reintentos.
    """
    for intento in range(1, max_retries + 1):
        try:
            respuesta = requests.get(url, params=params)
            respuesta.raise_for_status()  # Lanza excepción si el código HTTP no es 200
            return respuesta.json()       # Si llegó aquí, todo bien
        except requests.exceptions.RequestException as e:
            print(f"Intento {intento} falló: {e}")
            if intento < max_retries:
                print(f"Esperando 5 segundos antes de reintentar...")
                time.sleep(5)
            else:
                print(f"Fallo después de {max_retries} intentos.")
                return None

# %%
params_metricas = {
            "part": "contentDetails,snippet,statistics",
            "id": "1K9aTbPe8nc",
            "key": API_KEY
        }

metricas_url = "https://www.googleapis.com/youtube/v3/videos"

lista_metricas_url = hacer_peticion(metricas_url, params=params_metricas)

if "items" not in lista_metricas_url:
    print("Advertencia: respuesta sin items", lista_metricas_url)

# %%
consulta_formateada = json.dumps(lista_metricas_url, indent=2)
print(consulta_formateada)
# Out:
# {
#   "kind": "youtube#videoListResponse",
#   "etag": "F_VDsAhTBmygb2I4_C4oO2dgYpQ",
#   "items": [
#     {
#       "kind": "youtube#video",
#       "etag": "mMKunqvRGY2psAUdOdSNMQLiyEM",
#       "id": "1K9aTbPe8nc",
#       "snippet": {
#         "publishedAt": "2026-03-12T18:01:09Z",
#         "channelId": "UCOQEA3qmyzFmJdi6Z137yrA",
#         "title": "\u00bfSi tu profe es tan INTELIGENTE por qu\u00e9 es POBRE?",
#         "description": "Este video ensayo explora la paradoja entre inteligencia y dinero: \u00bfpor qu\u00e9 tu profesor de historia vive en un monoambiente mientras un chico sin estudios presume de riqueza? Analizo la relaci\u00f3n entre conocimiento, inteligencia y prosperidad, desmontando mitos como el de \u201clos humanistas son pobres porque son tontos\u201d y cuestionando fen\u00f3menos contempor\u00e1neos como las criptomonedas. Con datos de Am\u00e9rica Latina sobre la brecha salarial entre universitarios y quienes solo tienen educaci\u00f3n b\u00e1sica, reflexiono sobre la falacia ad crumenam y el principio epic\u00fareo: no es m\u00e1s feliz quien m\u00e1s tiene, sino quien menos necesita. Borges, Vargas Llosa, MrBeast y Amadeo Llad\u00f3s aparecen como s\u00edmbolos contrapuestos de lujo, modestia y viralidad. Palabras clave: inteligencia, dinero, filosof\u00eda, criptomonedas, educaci\u00f3n, pobreza, riqueza, Borges, Vargas Llosa, felicidad, ad crumenam, epicure\u00edsmo, lujo vulgaridad.\n\nMi libro: https://amzn.to/3tvlXwp\n\n\u25bc\u25bc SOBRE EL CANAL \u25bc\u25bc\n\nMonitor fantasma es un canal de videoensayos en el que se trata temas culturales y de actualidad. Sin embargo, y puesto que el discurso pertenece al g\u00e9nero argumentativo,  el mensaje no debe ser tomado como un hecho sino como una opini\u00f3n personal. Lo que est\u00e1s viendo es contenido de autor. El uso de Inteligencias artificiales se ha limitado como motor de b\u00fasqueda y generaci\u00f3n de im\u00e1genes y sonidos de apoyo. \u00a1Mantengamos la internet humana!\n\nLa l\u00ednea editorial del canal: https://youtu.be/TqZQL9ol-Pw\n\n\u25bc\u25bc  MIS REDES \u25bc\u25bc\n\nPATREON: https://www.patreon.com/monitorfantasma\nE-MAIL (Solo Contratos): jaguirreeditor@gmail.com \nMI CANAL SECUNDARIO: http://bit.ly/2ub3NBv\n\n\u25bc\u25bc C\u00d3MO CITAR ESTE VIDEO (APA) \u25bc\u25bc\n\nAguirre, Josu\u00e9. [Monitor Fantasma] (12/03/2026). \u00bfInteligencia sin dinero o dinero sin inteligencia? [Archivo de Video]. Youtube. https://youtu.be/1K9aTbPe8nc\n\n\u25bc\u25bc Sobre el uso de im\u00e1genes y clips de video \u25bc\u25bc\n\nEste video puede contar con im\u00e1genes y material f\u00edlmico que no es propiedad del autor. Dicho material puede ser libre de derechos o protegido. Su empleo, en el segundo caso, se realiza bajo el criterio del uso justo o Fair Use.\n\n#Filosofia #Educaci\u00f3n\n#Inteligencia\n#Dinero\n#Filosof\u00eda\n#Criptomonedas\n#Educaci\u00f3n\n#Pobreza\n#Riqueza\n#Borges\n#VargasLlosa\n#Epicure\u00edsmo\n#Lujo",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/1K9aTbPe8nc/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/1K9aTbPe8nc/mqdefault.jpg",
#             "width": 320,
#             "height": 180
#           },
#           "high": {
#             "url": "https://i.ytimg.com/vi/1K9aTbPe8nc/hqdefault.jpg",
#             "width": 480,
#             "height": 360
#           },
#           "standard": {
#             "url": "https://i.ytimg.com/vi/1K9aTbPe8nc/sddefault.jpg",
#             "width": 640,
#             "height": 480
#           },
#           "maxres": {
#             "url": "https://i.ytimg.com/vi/1K9aTbPe8nc/maxresdefault.jpg",
#             "width": 1280,
#             "height": 720
#           }
#         },
#         "channelTitle": "Monitor fantasma",
#         "tags": [
#           "Filosof\u00eda",
#           "philosophy",
#           "Education",
#           "Educaci\u00f3n"
#         ],
#         "categoryId": "27",
#         "liveBroadcastContent": "none",
#         "defaultLanguage": "es",
#         "localized": {
#           "title": "\u00bfSi tu profe es tan INTELIGENTE por qu\u00e9 es POBRE?",
#           "description": "Este video ensayo explora la paradoja entre inteligencia y dinero: \u00bfpor qu\u00e9 tu profesor de historia vive en un monoambiente mientras un chico sin estudios presume de riqueza? Analizo la relaci\u00f3n entre conocimiento, inteligencia y prosperidad, desmontando mitos como el de \u201clos humanistas son pobres porque son tontos\u201d y cuestionando fen\u00f3menos contempor\u00e1neos como las criptomonedas. Con datos de Am\u00e9rica Latina sobre la brecha salarial entre universitarios y quienes solo tienen educaci\u00f3n b\u00e1sica, reflexiono sobre la falacia ad crumenam y el principio epic\u00fareo: no es m\u00e1s feliz quien m\u00e1s tiene, sino quien menos necesita. Borges, Vargas Llosa, MrBeast y Amadeo Llad\u00f3s aparecen como s\u00edmbolos contrapuestos de lujo, modestia y viralidad. Palabras clave: inteligencia, dinero, filosof\u00eda, criptomonedas, educaci\u00f3n, pobreza, riqueza, Borges, Vargas Llosa, felicidad, ad crumenam, epicure\u00edsmo, lujo vulgaridad.\n\nMi libro: https://amzn.to/3tvlXwp\n\n\u25bc\u25bc SOBRE EL CANAL \u25bc\u25bc\n\nMonitor fantasma es un canal de videoensayos en el que se trata temas culturales y de actualidad. Sin embargo, y puesto que el discurso pertenece al g\u00e9nero argumentativo,  el mensaje no debe ser tomado como un hecho sino como una opini\u00f3n personal. Lo que est\u00e1s viendo es contenido de autor. El uso de Inteligencias artificiales se ha limitado como motor de b\u00fasqueda y generaci\u00f3n de im\u00e1genes y sonidos de apoyo. \u00a1Mantengamos la internet humana!\n\nLa l\u00ednea editorial del canal: https://youtu.be/TqZQL9ol-Pw\n\n\u25bc\u25bc  MIS REDES \u25bc\u25bc\n\nPATREON: https://www.patreon.com/monitorfantasma\nE-MAIL (Solo Contratos): jaguirreeditor@gmail.com \nMI CANAL SECUNDARIO: http://bit.ly/2ub3NBv\n\n\u25bc\u25bc C\u00d3MO CITAR ESTE VIDEO (APA) \u25bc\u25bc\n\nAguirre, Josu\u00e9. [Monitor Fantasma] (12/03/2026). \u00bfInteligencia sin dinero o dinero sin inteligencia? [Archivo de Video]. Youtube. https://youtu.be/1K9aTbPe8nc\n\n\u25bc\u25bc Sobre el uso de im\u00e1genes y clips de video \u25bc\u25bc\n\nEste video puede contar con im\u00e1genes y material f\u00edlmico que no es propiedad del autor. Dicho material puede ser libre de derechos o protegido. Su empleo, en el segundo caso, se realiza bajo el criterio del uso justo o Fair Use.\n\n#Filosofia #Educaci\u00f3n\n#Inteligencia\n#Dinero\n#Filosof\u00eda\n#Criptomonedas\n#Educaci\u00f3n\n#Pobreza\n#Riqueza\n#Borges\n#VargasLlosa\n#Epicure\u00edsmo\n#Lujo"
#         },
#         "defaultAudioLanguage": "es"
#       },
#       "contentDetails": {
#         "duration": "PT9M42S",
#         "dimension": "2d",
#         "definition": "hd",
#         "caption": "false",
#         "licensedContent": true,
#         "contentRating": {},
#         "projection": "rectangular"
#       },
#       "statistics": {
#         "viewCount": "25180",
#         "likeCount": "2140",
#         "favoriteCount": "0",
#         "commentCount": "195"
#       }
#     }
#   ],
#   "pageInfo": {
#     "totalResults": 1,
#     "resultsPerPage": 1
#   }
# }
